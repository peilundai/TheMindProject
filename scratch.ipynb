# %%
import numpy as np
import torch
import random
# %matplotlib inline

# %% [markdown]
# ## Definining related classes

# %%
class Player:

    def __init__(self, name, level):
        self.name = name
        self.level = level
        self.cards = []
        self.timer = np.inf
        self.aggresiveness = np.random.random_integers(low=1, high=3)

    def __str__(self):
        return "Name: " + str(self.name) + '\n' + "Cards: " + str(self.cards)

    def get_name(self):
        return self.name

    def set_level(self, level):
        self.level = level

    def draw_cards(self, deck):
        self.cards = deck.get_all_cards()[-self.level:]
        deck.set_cards(deck.get_all_cards()[:-self.level])

    def remove_card(self, card):
        if card not in self.cards:
            print("You don't have card ", str(card))
            print("Please choose another card")
        self.cards.remove(card)

    def play_card(self, table):
        if not self.is_empty_hand():
            # if card not in self.cards:
            #     print("You don't have card ", str(card))
            #     print("Please choose another card")
            # else:
            smallest_card = min(self.cards)
            self.remove_card(smallest_card)
            table.add_card(smallest_card)
            return smallest_card
        else:
            print(self.name, " has empty hand and cannot play the card.")

    def is_empty_hand(self):
        return len(self.cards) == 0

    def dec_timer(self):
        self.timer = self.timer - 1

    def read_timer(self):
        return self.timer

    def update_timer(self, table):
        # TODO
        self.timer = np.random.random_integers(
            low=1, high=5) * self.aggresiveness


class Table:

    def __init__(self):
        self.cards = []

    def __str__(self):
        return str(self.show_all_cards())

    def add_card(self, card):
        self.cards.append(card)

    def show_all_cards(self):
        return self.cards

    def show_top_card(self):
        return self.cards[-1]


class Deck:

    def __init__(self, total_num_cards):
        all_cards = np.arange(total_num_cards) + 1
        np.random.shuffle(all_cards)
        self.deck = all_cards.tolist()

    def __str__(self):
        pass

    def get_all_cards(self):
        return self.deck

    def set_cards(self, new_cards):
        self.deck = new_cards


class Clock:

    def __init__(self):
        self.time = 0

    def __str__(self):
        return "Current time step is " + str(self.time)

    def read_time(self):
        return self.time

    def step(self):
        self.time = self.time + 1

    def reset(self):
        self.time = 0


class Game:

    def __init__(self, player_names, level, total_num_cards, verbose=False):
        self.player_names = player_names
        self.players_list = [Player(name, level) for name in player_names]
        self.retired_players = []
        self.players = {
            player.get_name(): player for player in self.players_list}
        self.table = Table()
        self.deck = Deck(total_num_cards)
        self.clock = Clock()
        self.game_ended = False
        self.verbose = verbose

    def step(self):
        self.clock.step()
        if self.verbose:
            print("\n ---------------- t =",
                  self.clock.read_time(), " ----------------")
        for player in self.players:
            if not self.players[player].is_empty_hand():
                self.players[player].dec_timer()
                # print(self.players[player].read_timer())

        any_play = [i for i in range(len(self.players_list)) if self.players_list[i].read_timer(
        ) == 0 and not self.players_list[i].is_empty_hand()]
        # print(any_play)
        if not len(any_play) == 0:
            chosen_player = random.choice(any_play)
            print("* Chosen player: ",
                  self.players_list[chosen_player].get_name(), "\n")
            played_card = self.players_list[chosen_player].play_card(
                self.table)
            # print(self.players_list[chosen_player].name, " played ", str(played_card))
            for player in self.players_list:
                player.update_timer(self.table)

        not_all_empty = False
        for player in self.players_list:
            not_all_empty = not_all_empty or not player.is_empty_hand()
        self.game_ended = not not_all_empty

        # display states for each player
        if self.verbose == True:
            for ind in self.players:
                current_player = self.players[ind]
                print(current_player.get_name(), ": timer=",
                      current_player.read_timer(), "; hands=", current_player.cards)
            print("On the table: ", self.table.show_all_cards())
    def play(self):
        for player in self.players_list:
            player.draw_cards(self.deck)
            player.update_timer(self.table)

        while (self.game_ended == False):
        # for p in range(10):
            self.step()

# %% [markdown]
# ## Client code

# %%
    players = ["Ellen", "James", "Peilun"]
    g = Game(players, level=3, total_num_cards=10, verbose=True)
    g.play()
# Out:
#  ---------------- t = 1  ----------------
# Ellen : timer= 5 ; hands= [6, 9, 1]
# James : timer= 4 ; hands= [4, 5, 7]
# Peilun : timer= 3 ; hands= [2, 3, 8]
# On the table:  []
#
#  ---------------- t = 2  ----------------
# Ellen : timer= 4 ; hands= [6, 9, 1]
# James : timer= 3 ; hands= [4, 5, 7]
# Peilun : timer= 2 ; hands= [2, 3, 8]
# On the table:  []
#
#  ---------------- t = 3  ----------------
# Ellen : timer= 3 ; hands= [6, 9, 1]
# James : timer= 2 ; hands= [4, 5, 7]
# Peilun : timer= 1 ; hands= [2, 3, 8]
# On the table:  []
#
#  ---------------- t = 4  ----------------
# * Chosen player:  Peilun
#
# Ellen : timer= 8 ; hands= [6, 9, 1]
# James : timer= 5 ; hands= [4, 5, 7]
# Peilun : timer= 6 ; hands= [3, 8]
# On the table:  [2]
#
#  ---------------- t = 5  ----------------
# Ellen : timer= 7 ; hands= [6, 9, 1]
# James : timer= 4 ; hands= [4, 5, 7]
# Peilun : timer= 5 ; hands= [3, 8]
# On the table:  [2]
#
#  ---------------- t = 6  ----------------
# Ellen : timer= 6 ; hands= [6, 9, 1]
# James : timer= 3 ; hands= [4, 5, 7]
# Peilun : timer= 4 ; hands= [3, 8]
# On the table:  [2]
#
#  ---------------- t = 7  ----------------
# Ellen : timer= 5 ; hands= [6, 9, 1]
# James : timer= 2 ; hands= [4, 5, 7]
# Peilun : timer= 3 ; hands= [3, 8]
# On the table:  [2]
#
#  ---------------- t = 8  ----------------
# Ellen : timer= 4 ; hands= [6, 9, 1]
# James : timer= 1 ; hands= [4, 5, 7]
# Peilun : timer= 2 ; hands= [3, 8]
# On the table:  [2]
#
#  ---------------- t = 9  ----------------
# * Chosen player:  James
#
# Ellen : timer= 8 ; hands= [6, 9, 1]
# James : timer= 1 ; hands= [5, 7]
# Peilun : timer= 2 ; hands= [3, 8]
# On the table:  [2, 4]
#
#  ---------------- t = 10  ----------------
# * Chosen player:  James
#
# Ellen : timer= 6 ; hands= [6, 9, 1]
# James : timer= 3 ; hands= [7]
# Peilun : timer= 10 ; hands= [3, 8]
# On the table:  [2, 4, 5]
#
#  ---------------- t = 11  ----------------
# Ellen : timer= 5 ; hands= [6, 9, 1]
# James : timer= 2 ; hands= [7]
# Peilun : timer= 9 ; hands= [3, 8]
# On the table:  [2, 4, 5]
#
#  ---------------- t = 12  ----------------
# Ellen : timer= 4 ; hands= [6, 9, 1]
# James : timer= 1 ; hands= [7]
# Peilun : timer= 8 ; hands= [3, 8]
# On the table:  [2, 4, 5]
#
#  ---------------- t = 13  ----------------
# * Chosen player:  James
#
# Ellen : timer= 8 ; hands= [6, 9, 1]
# James : timer= 3 ; hands= []
# Peilun : timer= 2 ; hands= [3, 8]
# On the table:  [2, 4, 5, 7]
#
#  ---------------- t = 14  ----------------
# Ellen : timer= 7 ; hands= [6, 9, 1]
# James : timer= 3 ; hands= []
# Peilun : timer= 1 ; hands= [3, 8]
# On the table:  [2, 4, 5, 7]
#
#  ---------------- t = 15  ----------------
# * Chosen player:  Peilun
#
# Ellen : timer= 2 ; hands= [6, 9, 1]
# James : timer= 5 ; hands= []
# Peilun : timer= 6 ; hands= [8]
# On the table:  [2, 4, 5, 7, 3]
#
#  ---------------- t = 16  ----------------
# Ellen : timer= 1 ; hands= [6, 9, 1]
# James : timer= 5 ; hands= []
# Peilun : timer= 5 ; hands= [8]
# On the table:  [2, 4, 5, 7, 3]
#
#  ---------------- t = 17  ----------------
# * Chosen player:  Ellen
#
# Ellen : timer= 8 ; hands= [6, 9]
# James : timer= 3 ; hands= []
# Peilun : timer= 4 ; hands= [8]
# On the table:  [2, 4, 5, 7, 3, 1]
#
#  ---------------- t = 18  ----------------
# Ellen : timer= 7 ; hands= [6, 9]
# James : timer= 3 ; hands= []
# Peilun : timer= 3 ; hands= [8]
# On the table:  [2, 4, 5, 7, 3, 1]
#
#  ---------------- t = 19  ----------------
# Ellen : timer= 6 ; hands= [6, 9]
# James : timer= 3 ; hands= []
# Peilun : timer= 2 ; hands= [8]
# On the table:  [2, 4, 5, 7, 3, 1]
#
#  ---------------- t = 20  ----------------
# Ellen : timer= 5 ; hands= [6, 9]
# James : timer= 3 ; hands= []
# Peilun : timer= 1 ; hands= [8]
# On the table:  [2, 4, 5, 7, 3, 1]
#
#  ---------------- t = 21  ----------------
# * Chosen player:  Peilun
#
# Ellen : timer= 10 ; hands= [6, 9]
# James : timer= 5 ; hands= []
# Peilun : timer= 4 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8]
#
#  ---------------- t = 22  ----------------
# Ellen : timer= 9 ; hands= [6, 9]
# James : timer= 5 ; hands= []
# Peilun : timer= 4 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8]
#
#  ---------------- t = 23  ----------------
# Ellen : timer= 8 ; hands= [6, 9]
# James : timer= 5 ; hands= []
# Peilun : timer= 4 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8]
#
#  ---------------- t = 24  ----------------
# Ellen : timer= 7 ; hands= [6, 9]
# James : timer= 5 ; hands= []
# Peilun : timer= 4 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8]
#
#  ---------------- t = 25  ----------------
# Ellen : timer= 6 ; hands= [6, 9]
# James : timer= 5 ; hands= []
# Peilun : timer= 4 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8]
#
#  ---------------- t = 26  ----------------
# Ellen : timer= 5 ; hands= [6, 9]
# James : timer= 5 ; hands= []
# Peilun : timer= 4 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8]
#
#  ---------------- t = 27  ----------------
# Ellen : timer= 4 ; hands= [6, 9]
# James : timer= 5 ; hands= []
# Peilun : timer= 4 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8]
#
#  ---------------- t = 28  ----------------
# Ellen : timer= 3 ; hands= [6, 9]
# James : timer= 5 ; hands= []
# Peilun : timer= 4 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8]
#
#  ---------------- t = 29  ----------------
# Ellen : timer= 2 ; hands= [6, 9]
# James : timer= 5 ; hands= []
# Peilun : timer= 4 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8]
#
#  ---------------- t = 30  ----------------
# Ellen : timer= 1 ; hands= [6, 9]
# James : timer= 5 ; hands= []
# Peilun : timer= 4 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8]
#
#  ---------------- t = 31  ----------------
# * Chosen player:  Ellen
#
# Ellen : timer= 2 ; hands= [9]
# James : timer= 3 ; hands= []
# Peilun : timer= 6 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8, 6]
#
#  ---------------- t = 32  ----------------
# Ellen : timer= 1 ; hands= [9]
# James : timer= 3 ; hands= []
# Peilun : timer= 6 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8, 6]
#
#  ---------------- t = 33  ----------------
# * Chosen player:  Ellen
#
# Ellen : timer= 10 ; hands= []
# James : timer= 4 ; hands= []
# Peilun : timer= 10 ; hands= []
# On the table:  [2, 4, 5, 7, 3, 1, 8, 6, 9]
# /Users/pdai/miniconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: This function is deprecated. Please call randint(1, 3 + 1) instead
#
# /Users/pdai/miniconda3/envs/pytorch/lib/python3.6/site-packages/ipykernel_launcher.py:54: DeprecationWarning: This function is deprecated. Please call randint(1, 5 + 1) instead

# %%
for i in range(100):
    print(np.random.randint(low=1, high=11))
# Out:
# 2
# 4
# 9
# 9
# 9
# 10
# 8
# 2
# 6
# 3
# 9
# 4
# 9
# 4
# 7
# 1
# 7
# 3
# 4
# 1
# 9
# 8
# 6
# 5
# 4
# 4
# 1
# 3
# 4
# 4
# 8
# 10
# 9
# 1
# 2
# 10
# 3
# 1
# 6
# 9
# 9
# 2
# 5
# 5
# 9
# 3
# 5
# 3
# 7
# 3
# 4
# 5
# 10
# 7
# 3
# 9
# 10
# 8
# 4
# 8
# 2
# 7
# 6
# 1
# 6
# 5
# 8
# 7
# 1
# 4
# 2
# 2
# 2
# 8
# 7
# 4
# 1
# 9
# 2
# 7
# 8
# 4
# 6
# 8
# 8
# 2
# 6
# 7
# 2
# 1
# 9
# 2
# 5
# 7
# 10
# 10
# 1
# 7
# 8
# 10

# %%
# Out:
# array([30, 95])

# %%
a = []

# %%
a == []
# Out:
# True

# %%
import numpy as np
np.exp(-1/5)
# Out:
# 0.8187307530779818

# %%
for (ind, item) in enumerate([2, 3, 4, 5]):
    print(ind, item)
# Out:
# 0 2
# 1 3
# 2 4
# 3 5

# %%
min([2, 2, 5])
# Out:
# 2

# %%
a = {"haa":1, "2":2}

# %%
for key in a:
    print(key, a[key])
# Out:
# haa 1
# 2 2
